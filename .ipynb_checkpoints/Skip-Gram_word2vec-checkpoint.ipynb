# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
    
print('Done reading the file')
# Out:
# Text8 Dataset:  65%|██████▍   | 20.3M/31.3M [00:56<01:23, 132KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
print(int_words[0])
# Out:
# 5233

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    if (idx - R > 0):
        start = idx-R
    else:
        start = 0
    stop = idx+R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6443 0.4867 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6104 0.5252 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5184 0.3928 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5839 0.3890 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5182 0.3978 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5033 0.4105 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5295 0.3793 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5643 0.3743 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4774 0.3788 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4260 0.3899 sec/batch
# Nearest to zero: spiritual, fraternity, nevsky, tanakh, homework, diocesan, milton, ramses,
# Nearest to system: amur, acquiescence, modification, aimed, tamers, gunter, murdering, impersonal,
# Nearest to where: wootton, nassau, piggy, cataracts, ecclesial, amounted, emotions, dpp,
# Nearest to were: objective, brewery, os, scudetto, lynne, protrudes, driving, intact,
# Nearest to on: searching, kirov, gilpin, rundown, relays, yiddish, apollinaire, tptp,
# Nearest to only: of, lottie, saarinen, wfw, flexi, raucous, executioner, share,
# Nearest to all: hmas, corpse, hm, dumb, gillingham, presque, uttering, appreciating,
# Nearest to been: abscess, archdeacon, presheaf, considered, developing, scopes, duels, origine,
# Nearest to heavy: lying, musicality, lorenzini, domain, localised, radiation, noodles, jones,
# Nearest to bill: bilbao, kasz, epstein, giantess, two, hi, khalq, endothermy,
# Nearest to issue: kaoru, fabulous, bars, deciphered, feldman, pneumonic, revolutionize, mistletoe,
# Nearest to units: qpl, territories, arrays, goose, lothar, dhtml, permutations, likeable,
# Nearest to derived: pisin, dangling, intel, greenpeace, websters, outgassing, canonicity, lehrer,
# Nearest to additional: mortgages, finesse, barbarian, warranty, karenga, crisps, bismuth, modesty,
# Nearest to police: obstructive, agrarian, materialist, tea, regulus, circuit, felicity, finalised,
# Nearest to experience: galilee, belied, rumba, anatomical, procedural, sara, publicly, polytechnic,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4869 0.3884 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3799 0.3790 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3145 0.3759 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2145 0.3807 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1645 0.4085 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1794 0.4125 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1000 0.4242 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0437 0.4261 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0072 0.4700 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9636 0.5097 sec/batch
# Nearest to zero: spiritual, fraternity, tanakh, milton, colloquial, heated, nevsky, homework,
# Nearest to system: modification, aimed, tamers, earlier, amur, acquiescence, custom, wherever,
# Nearest to where: trade, constructed, nassau, emotions, wootton, piggy, attention, amounted,
# Nearest to were: objective, brewery, driving, medical, intact, any, os, kitchens,
# Nearest to on: searching, refers, relays, embedded, kirov, easier, remarked, yiddish,
# Nearest to only: of, being, share, correlation, lottie, saarinen, raucous, speed,
# Nearest to all: corpse, dumb, alternatively, celebrated, true, hm, pure, mother,
# Nearest to been: developing, considered, involving, abscess, weeks, documents, subjects, conclude,
# Nearest to heavy: lying, musicality, domain, radiation, sharpe, calista, championed, lorenzini,
# Nearest to bill: bilbao, economy, kasz, purpose, epstein, june, trio, hi,
# Nearest to issue: feldman, deciphered, bars, kaoru, fabulous, clive, power, mistletoe,
# Nearest to units: territories, part, identifying, goose, listing, permutations, slits, dhtml,
# Nearest to derived: pisin, intel, asserting, station, fill, dangling, greenpeace, c,
# Nearest to additional: streetcar, offered, parent, mortgages, fate, barbarian, failed, addiscombe,
# Nearest to police: obstructive, circuit, agrarian, tea, multiple, materialist, regulus, finalised,
# Nearest to experience: publicly, son, procedural, galilee, specific, anatomical, martyrdom, died,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9123 0.4659 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8800 0.4354 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8618 0.4528 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8570 0.4675 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8412 0.4229 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8159 0.4229 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7828 0.4306 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8068 0.3966 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7722 0.4547 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7776 0.4610 sec/batch
# Nearest to zero: fraternity, nevsky, milton, llama, easton, spiritual, tanakh, heated,
# Nearest to system: modification, aimed, amur, tamers, murdering, acquiescence, ps, earlier,
# Nearest to where: constructed, trade, wootton, emotions, nassau, cataracts, angle, amounted,
# Nearest to were: os, objective, brewery, intact, driving, restyled, protrudes, visigoth,
# Nearest to on: searching, refers, gilpin, relays, remarked, celebrates, yiddish, embedded,
# Nearest to only: correlation, of, freestyle, being, helmet, spiralling, wfw, saarinen,
# Nearest to all: corpse, dumb, decisive, pure, prominent, mother, ghent, maker,
# Nearest to been: conclude, weeks, subjects, abscess, involving, accounting, developing, considered,
# Nearest to heavy: lying, musicality, domain, radiation, championed, postulated, shipping, factory,
# Nearest to bill: bilbao, economy, hi, kasz, trio, epstein, june, template,
# Nearest to issue: bars, feldman, fabulous, mistletoe, kaoru, deciphered, wetlands, revolutionize,
# Nearest to units: goose, lothar, territories, listing, slits, dhtml, permutations, stacks,
# Nearest to derived: pisin, intel, asserting, greenpeace, station, fill, customs, dangling,
# Nearest to additional: parent, fate, streetcar, offered, mortgages, barbarian, crisps, popularized,
# Nearest to police: obstructive, agrarian, circuit, finalised, materialist, tea, likelihood, pace,
# Nearest to experience: publicly, galilee, procedural, son, anatomical, rebels, specific, martyrdom,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7928 0.4855 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7700 0.4875 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7190 0.4747 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7139 0.4882 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7389 0.4921 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6900 0.4793 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7017 0.4756 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7193 0.4780 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6925 0.4542 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6456 0.4438 sec/batch
# Nearest to zero: fraternity, llama, milton, nevsky, six, pupils, easton, one,
# Nearest to system: amur, modification, aimed, racers, acquiescence, murdering, impersonal, ps,
# Nearest to where: wootton, trade, constructed, nassau, emotions, cataracts, dpp, improbable,
# Nearest to were: os, intact, objective, brewery, bounced, visigoth, restyled, protrudes,
# Nearest to on: searching, gilpin, celebrates, refers, richmond, remarked, relays, jehoshaphat,
# Nearest to only: correlation, being, freestyle, of, spiralling, helmet, mammalian, romanticized,
# Nearest to all: dumb, corpse, decisive, pure, germ, kildare, true, prominent,
# Nearest to been: archdeacon, abscess, accounting, conclude, involving, weeks, considered, scopes,
# Nearest to heavy: lying, musicality, localised, postulated, factory, championed, radiation, domain,
# Nearest to bill: bilbao, kasz, economy, trio, june, epstein, bundles, basketball,
# Nearest to issue: fabulous, feldman, bars, kaoru, deciphered, revolutionize, mistletoe, correction,
# Nearest to units: goose, territories, qpl, lothar, listing, slits, arrays, intending,
# Nearest to derived: pisin, intel, asserting, greenpeace, dangling, outgassing, canonicity, computed,
# Nearest to additional: mortgages, streetcar, offered, barbarian, fate, parent, crisps, finesse,
# Nearest to police: obstructive, agrarian, finalised, regulus, materialist, potsdam, mcnab, pace,
# Nearest to experience: anatomical, galilee, procedural, publicly, sara, belied, specific, son,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6717 0.4658 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6509 0.4737 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6097 0.4634 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6468 0.4666 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6161 0.4794 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6109 0.4685 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6164 0.3468 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5631 0.4647 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5335 0.4605 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4933 0.4723 sec/batch
# Nearest to zero: two, one, fraternity, llama, six, total, three, lenard,
# Nearest to system: amur, modification, racers, default, acquiescence, ps, aimed, murdering,
# Nearest to where: wootton, constructed, trade, dpp, nassau, gagarin, cataracts, gehenna,
# Nearest to were: visigoth, os, brewery, intact, bounced, restyled, medical, protrudes,
# Nearest to on: searching, gilpin, celebrates, refers, remarked, comical, jehoshaphat, secretive,
# Nearest to only: correlation, being, of, mammalian, romanticized, helmet, spiralling, wfw,
# Nearest to all: dumb, pure, corpse, decisive, germ, monistic, kildare, hmas,
# Nearest to been: accounting, abscess, archdeacon, conclude, traverse, presheaf, involving, origine,
# Nearest to heavy: musicality, lying, localised, factory, postulated, radiation, domain, shipping,
# Nearest to bill: bilbao, kasz, basketball, june, trio, patinkin, davis, epstein,
# Nearest to issue: kaoru, fabulous, revolutionize, feldman, correction, deciphered, partridge, bars,
# Nearest to units: goose, territories, slits, qpl, dhtml, stacks, arrays, permutations,
# Nearest to derived: pisin, asserting, intel, needless, greenpeace, letter, dangling, outgassing,
# Nearest to additional: mortgages, parent, fate, offered, crisps, streetcar, warranty, addiscombe,
# Nearest to police: finalised, obstructive, agrarian, regulus, felicity, potsdam, mcnab, materialist,
# Nearest to experience: anatomical, procedural, specific, sara, galilee, belied, publicly, rumba,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4916 0.4668 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5031 0.4585 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4953 0.4609 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5306 0.4641 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4877 0.4570 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4698 0.4676 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4847 0.4594 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4098 0.4905 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4242 0.4589 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4250 0.4452 sec/batch
# Nearest to zero: total, two, llama, six, km, three, one, transpersonal,
# Nearest to system: amur, modification, default, aimed, racers, applications, generator, ps,
# Nearest to where: wootton, constructed, angle, dpp, cataracts, gagarin, trade, engrailed,
# Nearest to were: intact, visigoth, brewery, bounced, restyled, lotharingia, os, phobos,
# Nearest to on: searching, gilpin, celebrates, release, apollinaire, relays, remarked, refers,
# Nearest to only: correlation, being, of, wfw, helmet, curved, flexi, spiralling,
# Nearest to all: dumb, hmas, corpse, germ, pure, alternatively, monistic, equivalence,
# Nearest to been: archdeacon, abscess, accounting, presheaf, conclude, involving, weeks, altruism,
# Nearest to heavy: musicality, lying, localised, domain, factory, postulated, pipes, lorenzini,
# Nearest to bill: bilbao, basketball, kasz, trio, davis, june, epstein, patinkin,
# Nearest to issue: fabulous, partridge, revolutionize, sayonara, feldman, kaoru, power, showroom,
# Nearest to units: goose, slits, territories, permutations, dhtml, qpl, stacks, arrays,
# Nearest to derived: pisin, letter, asserting, websters, needless, dangling, canonicity, computed,
# Nearest to additional: mortgages, warranty, crisps, streetcar, parent, fate, deviation, offered,
# Nearest to police: finalised, obstructive, agrarian, regulus, potsdam, felicity, mcnab, materialist,
# Nearest to experience: procedural, specific, belied, anatomical, sara, insufficient, galilee, rumba,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4308 0.3836 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4161 0.3746 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4324 0.3729 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3902 0.3777 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4133 0.3740 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4572 0.3717 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4021 0.3794 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3869 0.4614 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4338 0.5763 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4027 0.4987 sec/batch
# Nearest to zero: two, total, six, one, three, four, llama, migrant,
# Nearest to system: amur, modification, aimed, racers, default, ps, generator, applications,
# Nearest to where: angle, constructed, wootton, plows, foodcrops, engrailed, emotions, gehenna,
# Nearest to were: visigoth, intact, bounced, organising, os, brewery, restyled, lotharingia,
# Nearest to on: searching, gilpin, release, refers, exmoor, celebrates, freak, relays,
# Nearest to only: correlation, of, being, curved, collisions, flexi, vowels, wfw,
# Nearest to all: dumb, pure, true, germ, equivalence, nilpotent, corpse, alternatively,
# Nearest to been: archdeacon, abscess, accounting, presheaf, conclude, involving, altruism, mycenean,
# Nearest to heavy: musicality, lying, factory, lorenzini, localised, pipes, postulated, noodles,
# Nearest to bill: bilbao, trio, basketball, kasz, davis, epstein, texan, june,
# Nearest to issue: showroom, power, sayonara, partridge, colonialists, revolutionize, aristides, agreement,
# Nearest to units: goose, slits, territories, permutations, dhtml, measurements, flats, listing,
# Nearest to derived: pisin, letter, websters, asserting, dangling, needless, hyatt, canonicity,
# Nearest to additional: mortgages, crisps, warranty, offered, streetcar, addiscombe, deviation, bismuth,
# Nearest to police: finalised, agrarian, regulus, obstructive, potsdam, millay, likelihood, materialist,
# Nearest to experience: procedural, specific, anatomical, sara, belied, insufficient, isotropy, rumba,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3565 0.4446 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3932 0.4260 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3653 0.4225 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3909 0.4499 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3697 0.4287 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3692 0.4184 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3786 0.4163 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3903 0.4218 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3326 0.4227 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3347 0.4137 sec/batch
# Nearest to zero: two, six, four, one, three, total, seven, migrant,
# Nearest to system: amur, modification, racers, default, aimed, generator, ps, indexing,
# Nearest to where: constructed, angle, wootton, plows, foodcrops, emotions, cataracts, improbable,
# Nearest to were: visigoth, restyled, organising, intact, parte, bounced, brewery, lotharingia,
# Nearest to on: searching, gilpin, release, celebrates, refers, exmoor, lner, cryogenic,
# Nearest to only: correlation, of, being, curved, collisions, romanticized, flexi, mammalian,
# Nearest to all: dumb, nilpotent, equivalence, germ, monistic, pure, true, possess,
# Nearest to been: archdeacon, abscess, presheaf, conclude, accounting, mycenean, luckily, traverse,
# Nearest to heavy: factory, musicality, pipes, lying, lorenzini, noodles, localised, calista,
# Nearest to bill: bilbao, trio, kasz, reconsideration, texan, basketball, davis, june,
# Nearest to issue: power, showroom, sayonara, partridge, agreement, colonialists, aristides, haji,
# Nearest to units: goose, territories, slits, permutations, flats, lothar, listing, kilometers,
# Nearest to derived: pisin, letter, websters, asserting, hyatt, usage, phrase, friesland,
# Nearest to additional: mortgages, crisps, warranty, addiscombe, culling, streetcar, finesse, offered,
# Nearest to police: finalised, agrarian, regulus, potsdam, obstructive, nda, recruited, millay,
# Nearest to experience: procedural, specific, belied, anatomical, sara, attempted, insufficient, rumba,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3605 0.4451 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2924 0.4827 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3715 0.3917 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3816 0.3835 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4034 0.3891 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3030 0.4248 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3162 0.4097 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3670 0.4410 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2267 0.3778 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2832 0.3819 sec/batch
# Nearest to zero: two, one, six, three, four, total, seven, migrant,
# Nearest to system: modification, amur, default, ps, aimed, generator, indexing, soc,
# Nearest to where: constructed, angle, wootton, plows, foodcrops, hiram, cataracts, odes,
# Nearest to were: visigoth, intact, bounced, organising, crusher, restyled, parte, driving,
# Nearest to on: searching, gilpin, release, celebrates, exmoor, refers, remarked, corbino,
# Nearest to only: correlation, being, of, romanticized, wfw, vowels, contradicts, flexi,
# Nearest to all: nilpotent, germ, equivalence, decisive, monistic, dumb, true, corpse,
# Nearest to been: archdeacon, abscess, presheaf, complaint, conclude, accounting, mycenean, bess,
# Nearest to heavy: factory, pipes, lorenzini, lying, musicality, calista, noodles, localised,
# Nearest to bill: bilbao, reconsideration, basketball, texan, trio, epstein, davis, kasz,
# Nearest to issue: showroom, power, partridge, agreement, aristides, colonialists, sayonara, fabulous,
# Nearest to units: goose, slits, territories, permutations, measurements, flats, lothar, dhtml,
# Nearest to derived: pisin, letter, websters, asserting, hyatt, reassurance, friesland, josephus,
# Nearest to additional: mortgages, crisps, addiscombe, warranty, finesse, streetcar, culling, watertight,
# Nearest to police: finalised, agrarian, potsdam, regulus, nda, millay, recruited, obstructive,
# Nearest to experience: sara, procedural, specific, belied, anatomical, aerobatic, attempted, rumba,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3076 0.4268 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2999 0.4702 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3541 0.1931 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2600 0.4552 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2564 0.4042 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2101 0.4458 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2079 0.4044 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2182 0.4142 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2152 0.4343 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1596 0.4471 sec/batch
# Nearest to zero: two, one, four, three, six, total, seven, migrant,
# Nearest to system: modification, default, generator, indexing, functionality, amur, implementations, platforms,
# Nearest to where: constructed, angle, plows, foodcrops, expressways, wootton, hiram, dpp,
# Nearest to were: intact, visigoth, organising, bounced, crusher, restyled, brewery, horrors,
# Nearest to on: searching, gilpin, refers, exmoor, celebrates, release, telecom, relays,
# Nearest to only: correlation, being, romanticized, wfw, minimization, gassing, flexi, collisions,
# Nearest to all: nilpotent, dumb, monistic, decisive, equivalence, corpse, oxen, alternatively,
# Nearest to been: archdeacon, presheaf, conclude, traverse, abscess, mycenean, complaint, accounting,
# Nearest to heavy: factory, lorenzini, pipes, noodles, musicality, calista, localised, shipping,
# Nearest to bill: bilbao, reconsideration, basketball, texan, davis, patinkin, trio, kasz,
# Nearest to issue: showroom, power, colonialists, haji, sayonara, aristides, agreement, fabulous,
# Nearest to units: goose, territories, permutations, slits, flats, dhtml, kilometers, measurements,
# Nearest to derived: pisin, letter, websters, asserting, josephus, usage, macromolecule, hyatt,
# Nearest to additional: mortgages, crisps, addiscombe, warranty, finesse, occupancy, culling, corners,
# Nearest to police: finalised, agrarian, regulus, nda, potsdam, millay, recruited, obstructive,
# Nearest to experience: specific, attempted, procedural, sara, anatomical, belied, aerobatic, publicly,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2666 0.5031 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1883 0.4015 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2038 0.4309 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1219 0.3968 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1812 0.3834 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1584 0.3907 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1610 0.3695 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1910 0.5448 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2088 0.4656 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1834 0.3900 sec/batch
# Nearest to zero: two, three, four, one, six, total, migrant, seven,
# Nearest to system: indexing, modification, default, generator, ps, implementations, amur, soc,
# Nearest to where: constructed, angle, plows, foodcrops, elish, sweeps, skewness, unattended,
# Nearest to were: intact, organising, visigoth, bounced, crusher, driving, restyled, os,
# Nearest to on: searching, gilpin, refers, release, exmoor, celebrates, relays, up,
# Nearest to only: correlation, flexi, being, of, minimization, collisions, wfw, curved,
# Nearest to all: nilpotent, dumb, equivalence, alternatively, true, germ, monistic, oxen,
# Nearest to been: archdeacon, conclude, presheaf, abscess, mycenean, complaint, beaverbrook, traverse,
# Nearest to heavy: factory, pipes, lorenzini, noodles, musicality, calista, injection, bouncing,
# Nearest to bill: bilbao, reconsideration, trio, epstein, basketball, texan, patinkin, davis,
# Nearest to issue: showroom, power, haji, colonialists, sayonara, halt, fabulous, aristides,
# Nearest to units: goose, territories, permutations, flats, slits, kilometers, dhtml, lothar,
# Nearest to derived: pisin, letter, websters, macromolecule, josephus, coronet, hyatt, usage,
# Nearest to additional: mortgages, crisps, warranty, addiscombe, designs, finesse, occupancy, offered,
# Nearest to police: finalised, agrarian, regulus, recruited, obstructive, nda, millay, likelihood,
# Nearest to experience: specific, anatomical, procedural, belied, insufficient, attempted, aerobatic, sara,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1994 0.3965 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2116 0.3910 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1728 0.3890 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1575 0.3895 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2049 0.3921 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1766 0.3897 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2136 0.3923 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1787 0.3886 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1342 0.3890 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1873 0.3889 sec/batch
# Nearest to zero: two, six, one, four, three, total, migrant, seven,
# Nearest to system: indexing, modification, soc, amur, generator, joint, ps, borrowings,
# Nearest to where: constructed, angle, plows, foodcrops, skewness, piggy, ellipsoidal, ell,
# Nearest to were: intact, visigoth, organising, crusher, bounced, os, restyled, driving,
# Nearest to on: searching, exmoor, gilpin, refers, release, needless, celebrates, up,
# Nearest to only: correlation, flexi, being, minimization, curved, collisions, wfw, adrastea,
# Nearest to all: nilpotent, dumb, true, equivalence, oxen, alternatively, monistic, kildare,
# Nearest to been: archdeacon, complaint, beaverbrook, conclude, presheaf, traverse, mycenean, abscess,
# Nearest to heavy: factory, lorenzini, pipes, noodles, shipping, stipulations, calista, musicality,
# Nearest to bill: bilbao, reconsideration, trio, condoleezza, basketball, epstein, texan, patinkin,
# Nearest to issue: showroom, haji, colonialists, halt, prejudices, power, fabulous, sayonara,
# Nearest to units: goose, territories, permutations, slits, flats, lothar, dhtml, kilometers,
# Nearest to derived: pisin, letter, websters, usage, josephus, macromolecule, coronet, phrase,
# Nearest to additional: mortgages, crisps, warranty, finesse, culling, lx, occupancy, addiscombe,
# Nearest to police: finalised, agrarian, recruited, nda, likelihood, millay, regulus, lewisham,
# Nearest to experience: specific, sara, anatomical, belied, insufficient, attempted, aerobatic, flavonoids,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1888 0.3969 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1542 0.3898 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1922 0.3892 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1799 0.3925 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1506 0.3948 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1520 0.3860 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1752 0.3901 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1512 0.3909 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1793 0.3907 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2000 0.3853 sec/batch
# Nearest to zero: two, three, one, six, four, seven, total, five,
# Nearest to system: indexing, amur, soc, borrowings, modification, joint, generator, borland,
# Nearest to where: constructed, plows, angle, foodcrops, kach, piggy, sweeps, hiram,
# Nearest to were: crusher, visigoth, intact, organising, restyled, bounced, lodgings, driving,
# Nearest to on: searching, gilpin, exmoor, celebrates, release, refers, richmond, pearlman,
# Nearest to only: correlation, flexi, wfw, being, minimization, montfort, romanticized, adrastea,
# Nearest to all: nilpotent, dumb, oxen, equivalence, true, celebrated, monistic, halved,
# Nearest to been: archdeacon, complaint, beaverbrook, conclude, presheaf, mycenean, altruism, bess,
# Nearest to heavy: factory, lorenzini, pipes, noodles, calista, shipping, stipulations, injection,
# Nearest to bill: bilbao, reconsideration, condoleezza, clinton, drafting, united, pickford, basketball,
# Nearest to issue: showroom, halt, haji, truthfully, colonialists, sayonara, power, prejudices,
# Nearest to units: territories, goose, lothar, permutations, slits, flats, kilometers, dhtml,
# Nearest to derived: pisin, letter, websters, coronet, lenstra, josephus, usage, phrase,
# Nearest to additional: mortgages, crisps, finesse, warranty, lx, culling, corners, watertight,
# Nearest to police: finalised, agrarian, recruited, millay, lewisham, nda, regulus, eichmann,
# Nearest to experience: specific, sara, anatomical, belied, aerobatic, procedural, flavonoids, pragmatism,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2141 0.3929 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1300 0.3884 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1432 0.3882 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1268 0.3902 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0502 0.3895 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1586 0.3891 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1581 0.3890 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1199 0.3871 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1525 0.0625 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1162 0.3880 sec/batch
# Nearest to zero: two, three, four, one, six, total, seven, five,
# Nearest to system: indexing, soc, generator, modification, borland, joint, gunter, borrowings,
# Nearest to where: constructed, plows, angle, sweeps, skewness, foodcrops, expressways, ell,
# Nearest to were: crusher, os, visigoth, organising, intact, restyled, bounced, driving,
# Nearest to on: searching, release, gilpin, exmoor, celebrates, refers, relays, corbino,
# Nearest to only: correlation, flexi, collisions, wfw, being, romanticized, misunderstood, gassing,
# Nearest to all: nilpotent, dumb, oxen, grothendieck, penchant, equivalence, decisive, demolished,
# Nearest to been: archdeacon, complaint, bess, traverse, beaverbrook, mycenean, conclude, altruism,
# Nearest to heavy: factory, pipes, lorenzini, noodles, calista, injection, shipping, musicality,
# Nearest to bill: bilbao, reconsideration, condoleezza, pickford, clinton, template, basketball, patinkin,
# Nearest to issue: showroom, halt, haji, colonialists, truthfully, prejudices, campylobacter, criticize,
# Nearest to units: territories, permutations, lothar, slits, flats, goose, dhtml, kilometers,
# Nearest to derived: pisin, websters, letter, coronet, lenstra, phrase, alliances, hyatt,
# Nearest to additional: crisps, mortgages, lx, warranty, offered, addiscombe, occupancy, culling,
# Nearest to police: finalised, agrarian, recruited, lewisham, circuit, nda, millay, eichmann,
# Nearest to experience: specific, sara, anatomical, flavonoids, procedural, aerobatic, belied, pragmatism,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1219 0.3940 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0650 0.3769 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0993 0.3796 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0529 0.3749 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0628 0.3754 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0669 0.3741 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0867 0.3729 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0830 0.3738 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1257 0.3747 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0215 0.3757 sec/batch
# Nearest to zero: two, three, one, four, six, total, seven, five,
# Nearest to system: indexing, generator, borland, gunter, successfully, functionality, borrowings, modification,
# Nearest to where: constructed, angle, sweeps, plows, skewness, foodcrops, gign, expressways,
# Nearest to were: crusher, intact, organising, visigoth, bounced, os, driving, lodgings,
# Nearest to on: searching, release, gilpin, refers, relays, celebrates, exmoor, up,
# Nearest to only: flexi, being, wfw, correlation, adrastea, collisions, montfort, gassing,
# Nearest to all: nilpotent, dumb, oxen, true, alternatively, grothendieck, equivalence, halved,
# Nearest to been: archdeacon, conclude, complaint, presheaf, mycenean, altruism, bess, beaverbrook,
# Nearest to heavy: lorenzini, pipes, factory, shipping, noodles, imperialists, injection, calista,
# Nearest to bill: bilbao, reconsideration, condoleezza, bledsoe, basketball, template, pickford, patinkin,
# Nearest to issue: showroom, halt, haji, fabulous, power, colonialists, campylobacter, sayonara,
# Nearest to units: territories, permutations, lothar, goose, dhtml, slits, flats, rambo,
# Nearest to derived: pisin, websters, letter, lenstra, coronet, unclear, macromolecule, alliances,
# Nearest to additional: crisps, lx, warranty, mortgages, finesse, watertight, addiscombe, corners,
# Nearest to police: finalised, agrarian, recruited, circuit, lewisham, obstructive, likelihood, eichmann,
# Nearest to experience: specific, anatomical, flavonoids, sara, procedural, currying, attempted, belied,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0585 0.3845 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0327 0.3744 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0230 0.3736 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0642 0.3736 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0602 0.3745 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0480 0.3736 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0687 0.3734 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1131 0.3720 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0546 0.3768 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0521 0.3745 sec/batch
# Nearest to zero: two, three, one, four, six, total, seven, five,
# Nearest to system: borrowings, indexing, successfully, generator, borland, gunter, joint, soc,
# Nearest to where: constructed, skewness, angle, ell, plows, sweeps, chickie, foodcrops,
# Nearest to were: crusher, intact, visigoth, organising, bounced, driving, os, restyled,
# Nearest to on: searching, celebrates, refers, gilpin, ltc, release, exmoor, hrvatska,
# Nearest to only: flexi, wfw, correlation, collisions, adrastea, minimization, being, of,
# Nearest to all: nilpotent, equivalence, true, dumb, oxen, symmetric, grothendieck, halved,
# Nearest to been: archdeacon, complaint, mycenean, conclude, presheaf, beaverbrook, luckily, traverse,
# Nearest to heavy: pipes, lorenzini, factory, injection, noodles, shipping, shipments, imperialists,
# Nearest to bill: bilbao, condoleezza, reconsideration, bledsoe, basketball, pickford, patinkin, drafting,
# Nearest to issue: showroom, haji, halt, colonialists, prejudices, fabulous, sayonara, evolutionists,
# Nearest to units: territories, slits, permutations, lothar, flats, goose, dhtml, rambo,
# Nearest to derived: pisin, websters, lenstra, macromolecule, letter, alliances, e, josephus,
# Nearest to additional: lx, crisps, offered, individual, mortgages, warranty, finesse, culling,
# Nearest to police: finalised, recruited, agrarian, circuit, likelihood, lewisham, eichmann, nda,
# Nearest to experience: specific, sara, anatomical, flavonoids, procedural, aerobatic, belied, attempted,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0782 0.3987 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0918 0.3756 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0662 0.3771 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0491 0.3717 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0760 0.3751 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0273 0.3749 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0685 0.3739 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0554 0.3754 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0928 0.3771 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0793 0.3876 sec/batch
# Nearest to zero: two, one, three, four, six, total, seven, five,
# Nearest to system: indexing, gunter, borrowings, successfully, generator, soc, borland, joint,
# Nearest to where: constructed, skewness, ell, chickie, angle, sweeps, plows, foodcrops,
# Nearest to were: visigoth, crusher, intact, modern, organising, lodgings, restyled, italians,
# Nearest to on: searching, celebrates, gilpin, release, refers, makran, march, remarked,
# Nearest to only: flexi, wfw, collisions, correlation, adrastea, untie, being, almost,
# Nearest to all: nilpotent, dumb, halved, true, equivalence, oxen, pure, celebrated,
# Nearest to been: archdeacon, complaint, mycenean, beaverbrook, bess, presheaf, loka, hyperlinks,
# Nearest to heavy: pipes, lorenzini, factory, noodles, injection, calista, championed, imperialists,
# Nearest to bill: reconsideration, bilbao, condoleezza, drafting, state, confidence, pickford, clinton,
# Nearest to issue: showroom, haji, halt, colonialists, fabulous, prejudices, sayonara, campylobacter,
# Nearest to units: territories, lothar, slits, permutations, goose, flats, dhtml, rambo,
# Nearest to derived: pisin, letter, phrase, websters, lenstra, coronet, alliances, e,
# Nearest to additional: lx, crisps, finesse, mortgages, individual, watertight, warranty, culling,
# Nearest to police: finalised, recruited, agrarian, eichmann, lewisham, likelihood, nda, circuit,
# Nearest to experience: specific, sara, anatomical, flavonoids, procedural, aerobatic, bid, currying,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0596 0.4927 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0386 0.4715 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0414 0.4590 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0603 0.3889 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0760 0.3899 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1148 0.4173 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1644 0.4485 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0505 0.4071 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0552 0.3902 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0657 0.4115 sec/batch
# Nearest to zero: two, one, three, four, six, total, five, seven,
# Nearest to system: borrowings, indexing, gunter, joint, successfully, modification, generator, diverging,
# Nearest to where: constructed, skewness, ell, sweeps, chickie, angle, plows, expressways,
# Nearest to were: crusher, visigoth, modern, intact, organising, peasantry, lodgings, electorate,
# Nearest to on: searching, release, gilpin, march, celebrates, makran, july, ltc,
# Nearest to only: flexi, wfw, collisions, correlation, untie, adrastea, being, gains,
# Nearest to all: nilpotent, halved, dumb, equivalence, celebrated, clitoridotomy, opposes, oxen,
# Nearest to been: complaint, archdeacon, mycenean, beaverbrook, loka, traverse, ncipe, hyperlinks,
# Nearest to heavy: pipes, lorenzini, factory, noodles, calista, imperialists, injection, shipments,
# Nearest to bill: reconsideration, bilbao, condoleezza, clinton, pickford, drafting, template, state,
# Nearest to issue: showroom, haji, halt, fabulous, campylobacter, colonialists, prejudices, controversy,
# Nearest to units: territories, slits, lothar, permutations, goose, rambo, dhtml, flats,
# Nearest to derived: phrase, pisin, letter, coronet, websters, lenstra, meaning, e,
# Nearest to additional: crisps, lx, watertight, finesse, romanized, vibrates, offered, culling,
# Nearest to police: finalised, recruited, agrarian, circuit, lewisham, eichmann, millay, likelihood,
# Nearest to experience: sara, specific, flavonoids, anatomical, procedural, aerobatic, loyalist, rumba,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0104 0.3981 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0346 0.3931 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0117 0.3951 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0565 0.3927 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0841 0.3926 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0516 0.3474 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0240 0.3912 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9796 0.3935 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0277 0.3954 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9688 0.3928 sec/batch
# Nearest to zero: two, one, four, three, six, total, seven, five,
# Nearest to system: indexing, gunter, successfully, borrowings, generator, dissipative, joint, mpc,
# Nearest to where: constructed, skewness, sweeps, in, ell, expressways, chickie, pharaoh,
# Nearest to were: crusher, visigoth, intact, modern, lodgings, exarchate, peasantry, organising,
# Nearest to on: searching, gilpin, celebrates, march, armageddon, remarked, baghdad, maxima,
# Nearest to only: flexi, wfw, being, collisions, adrastea, of, correlation, almost,
# Nearest to all: nilpotent, halved, celebrated, dumb, penchant, third, equivalence, demolished,
# Nearest to been: archdeacon, mycenean, complaint, that, presheaf, have, loka, conclude,
# Nearest to heavy: pipes, lorenzini, factory, injection, calista, noodles, bluesy, shipments,
# Nearest to bill: bilbao, reconsideration, condoleezza, pickford, clinton, template, drafting, patinkin,
# Nearest to issue: showroom, haji, halt, fabulous, colonialists, correction, prejudices, charisma,
# Nearest to units: territories, permutations, slits, goose, lothar, dhtml, prefix, rambo,
# Nearest to derived: phrase, pisin, coronet, lenstra, websters, letter, e, alliances,
# Nearest to additional: crisps, lx, offered, watertight, vibrates, flier, addiscombe, piano,
# Nearest to police: finalised, recruited, agrarian, likelihood, circuit, millay, eichmann, lewisham,
# Nearest to experience: specific, sara, anatomical, flavonoids, aerobatic, procedural, currying, irreconcilable,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9760 0.3966 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9738 0.3947 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9998 0.3914 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0211 0.3910 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9848 0.3939 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0071 0.3903 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9144 0.3897 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9493 0.3934 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9199 0.3894 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9748 0.3906 sec/batch
# Nearest to zero: two, one, three, four, six, five, seven, total,
# Nearest to system: borrowings, gunter, successfully, indexing, dissipative, borland, diverging, joint,
# Nearest to where: constructed, ell, skewness, sweeps, expressways, chickie, in, nucleosome,
# Nearest to were: crusher, intact, modern, visigoth, nomadic, exarchate, lodgings, peasantry,
# Nearest to on: searching, gilpin, celebrates, armageddon, march, nonstop, ltc, hrvatska,
# Nearest to only: being, flexi, wfw, adrastea, of, collisions, almost, untie,
# Nearest to all: nilpotent, dumb, equivalence, pure, penchant, celebrated, oxen, grothendieck,
# Nearest to been: complaint, that, archdeacon, have, mycenean, hyperlinks, beaverbrook, involving,
# Nearest to heavy: pipes, lorenzini, factory, shipments, calista, injection, bluesy, championed,
# Nearest to bill: bilbao, reconsideration, condoleezza, pickford, template, bledsoe, clinton, patinkin,
# Nearest to issue: showroom, haji, halt, prejudices, correction, campylobacter, fabulous, criticize,
# Nearest to units: territories, slits, goose, permutations, dhtml, prefix, rambo, lothar,
# Nearest to derived: pisin, phrase, coronet, alliances, macromolecule, websters, lenstra, letter,
# Nearest to additional: crisps, lx, watertight, vibrates, finesse, offered, aerodrome, or,
# Nearest to police: finalised, recruited, circuit, agrarian, likelihood, lewisham, eichmann, millay,
# Nearest to experience: specific, flavonoids, sara, anatomical, currying, procedural, galilee, irreconcilable,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9999 0.4025 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0428 0.3931 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9542 0.3904 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0342 0.3922 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0093 0.3903 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9412 0.3909 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9905 0.3921 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9980 0.3928 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9895 0.3926 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9982 0.3934 sec/batch
# Nearest to zero: two, one, three, four, six, seven, five, total,
# Nearest to system: borrowings, indexing, successfully, gunter, dissipative, diverging, borland, generator,
# Nearest to where: ell, constructed, skewness, in, sweeps, chickie, expressways, pharaoh,
# Nearest to were: crusher, modern, intact, had, visigoth, lodgings, cartoons, apostles,
# Nearest to on: searching, gilpin, release, nonstop, src, relays, july, celebrates,
# Nearest to only: flexi, wfw, adrastea, collisions, being, untie, almost, correlation,
# Nearest to all: nilpotent, dumb, pure, equivalence, penchant, celebrated, methuen, grothendieck,
# Nearest to been: complaint, that, have, archdeacon, mycenean, beaverbrook, knockout, hyperlinks,
# Nearest to heavy: pipes, lorenzini, shipments, calista, championed, factory, injection, nitrate,
# Nearest to bill: bilbao, reconsideration, condoleezza, template, pickford, clinton, bledsoe, drafting,
# Nearest to issue: showroom, haji, prejudices, halt, campylobacter, colonialists, fabulous, evolutionists,
# Nearest to units: slits, goose, permutations, lothar, dhtml, territories, rambo, conversion,
# Nearest to derived: phrase, pisin, e, lenstra, macromolecule, coronet, alliances, meaning,
# Nearest to additional: crisps, lx, finesse, watertight, offered, romanized, addiscombe, vibrates,
# Nearest to police: finalised, recruited, agrarian, circuit, criminal, likelihood, eichmann, obstructive,
# Nearest to experience: sara, specific, anatomical, flavonoids, currying, aerobatic, experiences, ccm,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0082 0.3928 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9977 0.3767 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9979 0.3768 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0085 0.3764 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0161 0.3771 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0102 0.3773 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9816 0.3758 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9675 0.3756 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9848 0.3744 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0265 0.3760 sec/batch
# Nearest to zero: two, one, four, six, three, five, seven, total,
# Nearest to system: successfully, borrowings, gunter, indexing, dissipative, diverging, joint, generator,
# Nearest to where: constructed, skewness, ell, sweeps, chickie, in, vacancy, expressways,
# Nearest to were: crusher, modern, had, peasantry, visigoth, nomadic, intact, captured,
# Nearest to on: searching, hrvatska, march, release, celebrates, baghdad, july, a,
# Nearest to only: flexi, wfw, being, untie, almost, of, adrastea, correlation,
# Nearest to all: nilpotent, pure, halved, third, equivalence, dumb, mitten, grothendieck,
# Nearest to been: complaint, have, that, involving, beaverbrook, archdeacon, loka, mycenean,
# Nearest to heavy: pipes, lorenzini, calista, shipments, factory, championed, smoker, nitrate,
# Nearest to bill: reconsideration, bilbao, condoleezza, clinton, state, pickford, template, drafting,
# Nearest to issue: showroom, haji, prejudices, campylobacter, halt, criticize, colonialists, fabulous,
# Nearest to units: slits, goose, territories, permutations, lothar, dhtml, rambo, conversion,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8244 0.4328 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8623 0.4969 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9183 0.5154 sec/batch
# Nearest to zero: two, six, three, one, four, five, seven, nine,
# Nearest to system: successfully, systems, borrowings, through, diverging, gunter, operating, universit,
# Nearest to where: is, in, ell, to, for, rooted, as, skewness,
# Nearest to were: had, crusher, was, early, handwritten, tyndareus, they, clashed,
# Nearest to on: a, the, and, by, from, of, one, all,
# Nearest to only: is, of, to, being, hunt, which, all, be,
# Nearest to all: for, of, a, there, is, in, nilpotent, to,
# Nearest to been: have, that, was, suspected, shortly, earliest, giant, complaint,
# Nearest to heavy: kamikazes, bolling, shipments, bluesy, riffs, som, carmine, bays,
# Nearest to bill: bilbao, template, clinton, shiloh, drafting, reconsideration, condoleezza, leahy,
# Nearest to issue: expands, fabulous, plutarch, showroom, haji, campylobacter, discount, controversy,
# Nearest to units: conversion, unit, uniforms, racial, prefix, goose, slits, dhtml,
# Nearest to derived: meaning, terms, coronet, xbox, e, lenstra, phrase, simply,
# Nearest to additional: crisps, mutating, vibrates, books, heterogeneity, tdi, preceding, tactic,
# Nearest to police: coulombs, recruited, finalised, carabineros, atocha, eichmann, millay, enforcement,
# Nearest to experience: buddha, experiencing, aerobatic, ccm, lou, anatomical, pragmatism, specific,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8251 0.4550 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8318 0.4276 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8449 0.4257 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8695 0.4273 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8629 0.4225 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9045 0.4343 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8525 0.4602 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8474 0.4329 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9012 0.4342 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8411 0.4349 sec/batch
# Nearest to zero: two, one, four, six, three, five, seven, nine,
# Nearest to system: systems, successfully, borrowings, universit, through, gunter, diverging, dissipative,
# Nearest to where: in, is, shoals, ell, rooted, moved, skewness, for,
# Nearest to were: had, was, crusher, early, handwritten, tyndareus, they, clashed,
# Nearest to on: a, and, the, by, of, one, is, march,
# Nearest to only: of, is, to, being, almost, has, hunt, three,
# Nearest to all: for, a, there, of, nilpotent, one, seven, is,
# Nearest to been: have, was, that, suspected, shortly, recent, involving, widespread,
# Nearest to heavy: bolling, kamikazes, shipments, som, riffs, rila, bays, bluesy,
# Nearest to bill: clinton, template, bilbao, condoleezza, drafting, reconsideration, shiloh, emphasising,
# Nearest to issue: fabulous, expands, haji, discount, controversy, showroom, plutarch, campylobacter,
# Nearest to units: conversion, unit, uniforms, racial, prefix, goose, rambo, slits,
# Nearest to derived: meaning, terms, coronet, xbox, e, phrase, lenstra, simply,
# Nearest to additional: crisps, mutating, vibrates, heterogeneity, books, their, tdi, dir,
# Nearest to police: coulombs, finalised, recruited, carabineros, eichmann, atocha, enforcement, handshaking,
# Nearest to experience: buddha, aerobatic, experiencing, anatomical, ccm, experiences, lou, pragmatism,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8518 0.4409 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8616 0.4365 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8473 0.4411 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8407 0.4366 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9010 0.4378 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8353 0.4378 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9384 0.4384 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9030 0.4377 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9298 0.4365 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8296 0.4351 sec/batch
# Nearest to zero: two, one, four, six, three, five, nine, seven,
# Nearest to system: systems, successfully, borrowings, universit, tributary, diverging, through, operating,
# Nearest to where: in, is, ell, for, to, if, shoals, moved,
# Nearest to were: had, was, crusher, handwritten, they, there, many, clashed,
# Nearest to on: a, and, the, by, one, of, in, from,
# Nearest to only: of, is, almost, to, has, being, hunt, which,
# Nearest to all: for, a, there, nilpotent, of, one, which, and,
# Nearest to been: have, was, that, suspected, widespread, shortly, involving, disciplining,
# Nearest to heavy: bolling, riffs, rila, kamikazes, som, bays, shipments, bluesy,
# Nearest to bill: clinton, shiloh, reconsideration, template, drafting, bilbao, condoleezza, emphasising,
# Nearest to issue: fabulous, expands, pat, plutarch, campylobacter, discount, showroom, controversy,
# Nearest to units: conversion, unit, uniforms, racial, prefix, white, slits, goose,
# Nearest to derived: meaning, terms, coronet, phrase, xbox, e, lenstra, simply,
# Nearest to additional: crisps, vibrates, books, mutating, tdi, heterogeneity, preceding, includes,
# Nearest to police: coulombs, recruited, carabineros, finalised, eichmann, atocha, enforcement, handshaking,
# Nearest to experience: buddha, aerobatic, lou, experiencing, ccm, anatomical, pragmatism, sara,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7740 0.4397 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8809 0.4360 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7690 0.4374 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8635 0.4379 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8203 0.4342 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8377 0.4360 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9056 0.2102 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8528 0.4390 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8298 0.4385 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8300 0.4375 sec/batch
# Nearest to zero: two, six, four, one, three, five, seven, nine,
# Nearest to system: systems, operating, successfully, diverging, tributary, vesa, universit, gunter,
# Nearest to where: in, ell, is, shoals, to, moved, for, sweeps,
# Nearest to were: had, was, early, crusher, tyndareus, handwritten, there, clashed,
# Nearest to on: a, the, and, of, by, in, from, s,
# Nearest to only: being, hunt, of, to, but, almost, is, although,
# Nearest to all: for, of, a, there, and, have, nilpotent, which,
# Nearest to been: have, was, that, suspected, earliest, recent, widespread, shortly,
# Nearest to heavy: bolling, kamikazes, riffs, rila, som, shipments, bluesy, bays,
# Nearest to bill: shiloh, clinton, bilbao, template, drafting, reconsideration, emphasising, condoleezza,
# Nearest to issue: fabulous, campylobacter, expands, plutarch, controversy, showroom, unfashionable, pat,
# Nearest to units: conversion, unit, uniforms, prefix, racial, slits, si, goose,
# Nearest to derived: meaning, terms, xbox, coronet, phrase, lenstra, e, simply,
# Nearest to additional: crisps, vibrates, mutating, tdi, tactic, includes, romanized, halfwidth,
# Nearest to police: coulombs, recruited, atocha, finalised, carabineros, eichmann, handshaking, paralysed,
# Nearest to experience: buddha, aerobatic, lou, ccm, experiencing, anatomical, sara, pragmatism,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7892 0.4413 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8378 0.4374 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8410 0.4378 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8034 0.4377 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8537 0.4367 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8327 0.4321 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8579 0.4373 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7503 0.4340 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7979 0.4381 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8083 0.4368 sec/batch
# Nearest to zero: two, six, three, one, four, five, seven, nine,
# Nearest to system: successfully, systems, operating, vesa, through, tributary, diverging, universit,
# Nearest to where: in, is, ell, to, for, rooted, moved, as,
# Nearest to were: had, was, early, they, handwritten, crusher, tyndareus, submergence,
# Nearest to on: a, and, the, of, by, in, other, one,
# Nearest to only: of, being, to, is, which, but, hunt, all,
# Nearest to all: a, of, for, there, which, is, nilpotent, in,
# Nearest to been: have, was, that, suspected, earliest, shortly, recent, documents,
# Nearest to heavy: kamikazes, bolling, shipments, rila, riffs, intern, som, bays,
# Nearest to bill: shiloh, clinton, template, drafting, bilbao, reconsideration, emphasising, leahy,
# Nearest to issue: fabulous, expands, campylobacter, plutarch, haji, controversy, discount, unfashionable,
# Nearest to units: conversion, unit, uniforms, prefix, racial, si, white, tri,
# Nearest to derived: meaning, terms, coronet, xbox, phrase, lenstra, simply, e,
# Nearest to additional: crisps, vibrates, mutating, books, tdi, includes, their, tactic,
# Nearest to police: recruited, coulombs, carabineros, finalised, atocha, handshaking, eichmann, enforcement,
# Nearest to experience: buddha, aerobatic, lou, experiencing, experiences, pragmatism, anatomical, ccm,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7464 0.4380 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8395 0.4354 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8522 0.4311 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8426 0.4351 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8162 0.4308 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8843 0.4351 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8510 0.4359 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8478 0.4339 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8117 0.4362 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8380 0.4372 sec/batch
# Nearest to zero: two, six, one, four, three, five, seven, nine,
# Nearest to system: systems, successfully, universit, operating, borrowings, through, lissajous, diverging,
# Nearest to where: is, in, ell, for, to, zoot, following, well,
# Nearest to were: had, was, early, handwritten, crusher, they, for, started,
# Nearest to on: a, and, the, by, of, in, is, one,
# Nearest to only: is, being, of, although, to, hunt, which, has,
# Nearest to all: for, of, a, there, which, in, and, have,
# Nearest to been: have, that, was, suspected, recent, widespread, earliest, which,
# Nearest to heavy: bolling, kamikazes, shipments, rila, riffs, bays, som, intern,
# Nearest to bill: shiloh, clinton, template, drafting, reconsideration, bilbao, emphasising, virial,
# Nearest to issue: fabulous, expands, discount, haji, campylobacter, plutarch, conservatives, pat,
# Nearest to units: conversion, unit, uniforms, racial, prefix, slits, white, tri,
# Nearest to derived: meaning, terms, xbox, coronet, phrase, lenstra, simply, choreographer,
# Nearest to additional: crisps, mutating, vibrates, books, includes, their, tdi, heterogeneity,
# Nearest to police: recruited, coulombs, carabineros, finalised, atocha, handshaking, eichmann, paralysed,
# Nearest to experience: buddha, aerobatic, experiencing, atlases, lou, experiences, ccm, dispensationalism,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8649 0.4433 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8476 0.4335 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8128 0.4382 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8336 0.4313 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8565 0.4334 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8245 0.4392 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8300 0.4304 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8602 0.4318 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8094 0.4336 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8056 0.3737 sec/batch
# Nearest to zero: two, six, one, four, three, five, seven, nine,
# Nearest to system: systems, successfully, operating, through, interesting, vesa, borrowings, tributary,
# Nearest to where: is, in, to, ell, well, for, if, zoot,
# Nearest to were: had, was, early, they, many, handwritten, there, over,
# Nearest to on: a, and, the, by, of, in, based, from,
# Nearest to only: is, of, to, being, which, in, although, has,
# Nearest to all: a, for, there, of, which, one, is, not,
# Nearest to been: have, was, that, suspected, which, shortly, the, widespread,
# Nearest to heavy: bolling, shipments, kamikazes, riffs, rila, som, bays, smoker,
# Nearest to bill: drafting, shiloh, reconsideration, clinton, template, bailiff, emphasising, bilbao,
# Nearest to issue: fabulous, expands, campylobacter, pat, discount, controversy, haji, plutarch,
# Nearest to units: conversion, unit, racial, uniforms, prefix, si, white, tri,
# Nearest to derived: meaning, terms, xbox, phrase, coronet, simply, lenstra, pers,
# Nearest to additional: crisps, or, mutating, their, vibrates, heterogeneity, includes, books,
# Nearest to police: recruited, coulombs, carabineros, finalised, atocha, eichmann, handshaking, warrants,
# Nearest to experience: buddha, aerobatic, experiencing, atlases, lou, pragmatism, experiences, ccm,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8486 0.3813 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8205 0.3778 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9222 0.3777 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9418 0.3770 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8959 0.3740 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8417 0.3742 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7996 0.3892 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8022 0.4309 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7181 0.4317 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8667 0.4333 sec/batch
# Nearest to zero: two, six, one, four, three, five, seven, nine,
# Nearest to system: systems, operating, successfully, through, tributary, and, interesting, universit,
# Nearest to where: in, is, to, for, ell, well, moved, if,
# Nearest to were: had, was, handwritten, early, they, elaborated, there, many,
# Nearest to on: a, and, the, by, of, in, an, based,
# Nearest to only: is, of, being, to, hunt, although, but, has,
# Nearest to all: for, a, of, there, and, in, have, nilpotent,
# Nearest to been: have, was, that, suspected, shortly, recent, involving, widespread,
# Nearest to heavy: bolling, kamikazes, rila, shipments, riffs, som, bays, smoker,
# Nearest to bill: shiloh, clinton, drafting, template, reconsideration, bilbao, emphasising, confirmed,
# Nearest to issue: fabulous, expands, pat, campylobacter, conservatives, plutarch, asa, discount,
# Nearest to units: conversion, unit, racial, prefix, uniforms, si, slits, white,
# Nearest to derived: meaning, terms, phrase, simply, coronet, xbox, pers, legend,
# Nearest to additional: crisps, vibrates, mutating, or, books, their, includes, tdi,
# Nearest to police: recruited, coulombs, finalised, carabineros, atocha, eichmann, handshaking, enforcement,
# Nearest to experience: buddha, aerobatic, lou, experiencing, ccm, atlases, dispensationalism, pragmatism,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8559 0.4419 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8231 0.4335 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
